# %% [markdown]
# ![image.png](attachment:image.png)
# -DI => POM.XML 안에 dependency 로 적어주는걸로 의존성 주입을해서 써왔었음

# %% [markdown]
# ![image.png](attachment:image.png)
# - 일반 java class 들이 POJO 라고함
# - 독립적임 ( 특정 라이브러리에 종속적이지 않음 )

# %% [markdown]
# ![image.png](attachment:image.png)
# - IoC (Inversion 역전 of Control)
# -> 원래 Control = 사용자가
# -> 역전=> Control = Spring이
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# 객체지향 프로그래밍 <-> "관점(객채 안에 있는기능) 지향 프로그래밍 (AOP)"
# - Advice=기능

# %% [markdown]
# ![image.png](attachment:image.png)
# - C : Controller

# %% [markdown]
# ![image.png](attachment:image.png)
# - Dispatcher Servlet = Front Controller 같은거
# - Handler Mapping : POJO 가 있는지 Dispatcher에게 알려주는것
# - Handelr Adapter : POJO가 있으면 여기를 통해 Controller로
# - DB에서 자료를 가져와서 Model에 저장해놈
# - 원래는 Member/Main.jsp 로 리턴하라고 반환하는데, Main 만 반환함
# - 다시 Dispatcher Servlet으로 주고
# - View Resolver에게 줘서 Main을 Member/Main.jsp 로 변환 (논리적인 이름으로 바꿔줌) (경로, 확장자 붙여줌)
# - 다시 Dispatcher Servlet에게 줘서 Model을 참조해서 View단에서 Response
# - 우리가 실제로 만들어야하는 것은 `Model, Controller, View`
#
# - 항상 실행할때는 Run As-> Run as server (Dispatcher로 실행하는것)
# - POJO 에서 @Controller 로 어노텐션으로 지정해줘야 Controller라고 인식함
# ![image-2.png](attachment:image-2.png)
# - Front Controller = 서블릿
# ![image-3.png](attachment:image-3.png)
# - request에서 / 로 요청이 들어올때 아래 코드를 실행시키겠다 (home을 반환)
# ![image-4.png](attachment:image-4.png)
# - 여기서는 setAttribute 가 아니라 addAttribute

# %% [markdown]
# ![image.png](attachment:image.png)
# - HomeController.java -> Handler
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# - 부트스트랩
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-4.png](attachment:image-4.png)
# s.count -> 1부터 알아서 증가하는 함수 ,$ 안에는 자바 함수 쓰면 안됨

# %% [markdown]
# ![image.png](attachment:image.png)
# .do로 여기로 가달라고 요청
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)
# ![image-4.png](attachment:image-4.png)
# - MYSQL : auto_increment -> 시퀀스 기능 알아서 해줌
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# - 실행 : alt + x
# ![image-7.png](attachment:image-7.png)
# - 블록을 다 씌우고 실행해야함

# %% [markdown]
# ![image.png](attachment:image.png)
# contextConfigLocation 을 찾을때 /WEB-INF/spring/root-context.xml 이 경로로 찾는다
# ## DBCP (DataBase Connection Pool) - 연결을 관리함. 우리는 HiKariCP를 사용
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# - 스크립트릿으로 한 경우는 빨간색 글씨처럼
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
